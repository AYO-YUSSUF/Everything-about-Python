# %% [markdown]
# #OOPS
# * Class
# * Object
# * Inheritance
# * Polymorphism

# %% [markdown]
# ###python - structured + object oriented

# %% [markdown]
# ## Class ------> Object
# ### Employee ----> Heemali, Mayur, Saurav etc
#
# ### Animals -----> Dog, Cat, Snakes, Cheetah, Panther
#
# ## Class is a logical entity while Object is a physical entity
#
# ## Class is a blue print and does not occupy space in memory.

# %% [markdown]
# ## Class -----> collection of variables (attributes) & methods (behaviour)

# %% [markdown]
# ### For one class, we can create multiple objects. Objects are independent.

# %% [markdown]
# ## Function --> we can create without class
#
# ## Method --> creates in side the class.

# %%
class MyClass:
   def myfunct(self):
     pass
   def display(self):
     print("Heems")
mc = MyClass()
mc.myfunct()
mc.display()
# Out:
# Heems

# %% [markdown]
# ## 2 types of methods we can define within the class
# * Instance method: we can call only through object
# * Static method: we can directly call using class

# %%
class MyClass:
  def m1(self):
    print("this is instance method...")
  @staticmethod
  def m2(self,num):
    print(self,num)

mc = MyClass()
mc.m1()
mc.m2(100,400)
# Out:
# this is instance method...
# 100 400

# %%
class MyClass:
  a,b=10,20
  def add(self):
    print(self.a+self.b)
  def mul(self):
    print(self.a*self.b)

mc=MyClass()
mc.mul()
# Out:
# 200

# %%
i,j=15,25

class Myclass:
  a,b=10,20    #class variables
  def add(self,x,y):
    print(x+y)   #local variables
    print(self.a+self.b)
    print(i+j) #global variables

mc=MyClass()

# %% [markdown]
# ## One class can have multiple objects

# %%
class MyClass:
  def display(self,name):
    print("this is display method")
    print(name)

obj1=MyClass()
obj1.display("Heems")

obj2=MyClass()
obj2.display("Chaudhari")
# Out:
# this is display method
# Heems
# this is display method
# Chaudhari

# %% [markdown]
# ## Method: Give any name, return the values method can take arguments/parameters we have to use an object to invoke the method.
#
# ## Constructor: constructor name is fixed: def __init__(self):
#
# ### Constructor will not return any value, constructor can also take arguments, constructor will be called at the time of the object creation itself.

# %%
#constructor example

class MyClass:
  def __init__(self):
    print("this is a constructor")
  def m1(self):
    print("hello")
  def m2(self,x,y):
    return(x+y)

mc=MyClass()
mc.m1()
mc.m2(10,20)
# Out:
# this is a constructor
# hello
# 30

# %%
class MyClass:
  name="heemali"
  def __init__(self,name): #Constructor expecting one more argument
    print(name)
    print(self.name)

mc=MyClass("Heemali") ##passing parameter to the constructor
# Out:
# Heemali
# heemali

# %%
#Req : EMP
#constructor:eid, ename, sal
#display: print eid, ename, sal

class Emp:
  def __init__(self, eid, ename, sal):
    self.eid=eid
    self.ename=ename
    self.sal=sal
  def display(self):
    print(self.eid,self.ename,self.sal)

e1=Emp(101,"Heemali",7000000)
e1.display()

e2=Emp(102,"Heems",6500000)
e2.display()
# Out:
# 101 Heemali 7000000
# 102 Heems 6500000

# %%
#Req : EMP
#constructor:eid, ename, sal
#display: print eid, ename, sal

class Emp:
  def __init__(self, eid, ename, sal):
    self.eid=eid
    self.ename=ename
    self.sal=sal
  def __str__(self):
    return f'{self.ename} {self.sal}' #using the string formatting method

e1=Emp(101,"Heemali",7000000)
print(e1)
# Out:
# Heemali 7000000

# %% [markdown]
# #INHERITANCE: ACQUIRING ALL THE ATTRIBUTES[VARIABLES] & BEHAVIOUR[METHODS] FROM ONE CLASS TO ANOTHER CLASS IS CALLED INHERITANCE.
#
# ## Class A ---> a,b,c  m1() m2() ---> A is parent of B class (Base Class/SUper Class)
#
# ## ClassB(A) ---> x,y,z  m3() ---> B is the child of A class (Sub Class/Derived Class)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Objectives of Inheritance
# * Code reusability
#
# * Avoids duplication

# %% [markdown]
# ## Types of Inheritance
#
# * Single
# * Multilevel
# * Hierarchy
# * Multiple

# %%
class A:
  def m1(self):
    print("This is m1 method from class A")

class B(A):
  def m2(self):
    print("This is m2 method from class B")

bobj=B()
bobj.m1()
bobj.m2()
# Out:
# This is m1 method from class A
# This is m2 method from class B

# %%
#single inheritance

class A:
  x,y=10,20
  def m1(self):
    print(self.x+self.y)

class B(A):
  a,b=200,100
  def m2(self):
    print(self.a-self.b)

bobj=B()
bobj.m1()
bobj.m2()
# Out:
# 30
# 100

# %%
#multilevel inheritance

class A:
  x,y=10,20
  def m1(self):
    print(self.x+self.y)

class B(A):
  a,b=200,100
  def m2(self):
    print(self.a-self.b)

class C(B):
  i,j=5,2
  def m3(self):
    print(self.i*self.j)

cobj=C()
cobj.m1()
cobj.m2()
cobj.m3()
# Out:
# 30
# 100
# 10

# %%
#Hierarchy Inheritance

class A:
  x,y=10,20
  def m1(self):
    print(self.x+self.y)

class B(A):
  a,b=200,100
  def m2(self):
    print(self.a-self.b)

class C(B):
  i,j=5,2
  def m3(self):
    print(self.i*self.j)

bobj=B()
bobj.m1()
bobj.m2()

cobj=C()
cobj.m1()
cobj.m2()
cobj.m3()
# Out:
# 30
# 100
# 30
# 100
# 10

# %%
#mutiple inheritance

class A:
  x,y=10,20
  def m1(self):
    print(self.x+self.y)

class B(A):
  a,b=200,100
  def m2(self):
    print(self.a-self.b)

#class C(A,B):
  i,j=5,2
  def m3(self):
    print(self.i*self.j)

cobj=C()
cobj.m1()
cobj.m2()
cobj.m3()
# Out:
# 30
# 100
# 10

# %%
#calling parent class method using child class (super())

class A:
  def m1(self):
    print("This is m1 method from Class A")

class B(A):
  def m1(self):
    print("this is m1 method from class b")
    super().m1()

bobj=B()
bobj.m1()
# Out:
# this is m1 method from class b
# This is m1 method from Class A

# %%
#overriding variables

class Parent:
  name="Heemali"

class Child(Parent):
  name="Mohan"

cobj=Child()
print(cobj.name)
# Out:
# Mohan

# %%
#overriding methods

class Bank:
  def rateofinterest(self):
    return 0

class XBank(Bank):
  def rateofinterest(self):
    return 10

class YBank(Bank):
  def rateofinterest(self):
    return 12

objx=XBank()
print(objx.rateofinterest())

objy=YBank()
print(objy.rateofinterest())
# Out:
# 10
# 12

# %% [markdown]
# #POLYMORPHISM

# %% [markdown]
# ### SHAPE ---- CIRCLE, RECTANGLE, SQUARE
#
# ## WE CAN IMPLEMENT POLYMORPHISM USING OVERLOADING CONCEPT

# %% [markdown]
# class
# * add(1,2)
# * add(1,2,3)
# * add(1,3,4,5)

# %% [markdown]
# user
# * add(10,20)
# * add(10,20,30)
# * add(10,30,40,50)

# %%
#overloading (Polymorphism)

class Human:
  def sayhello(self,name=None):
    if name is not None:
      print("Hello" +name)

h=Human()
h.sayhello("Heemali")
# Out:
# HelloHeemali

# %%
class Human:
  def sayhello(self,name=None):
    if name is not None:
      print("Hello" +name)
    else:
      print("Hello")

h=Human()
h.sayhello()
# Out:
# Hello

# %%
#overloading 2

class Calculation:
  def add(self,a=0,b=0,c=0):
    print(a+b+c)

calobj=Calculation()
calobj.add()
calobj.add(10,20)
calobj.add(100,200,300)
# Out:
# 0
# 30
# 600

# %% [markdown]
# # MODULES AND PACKAGES
#
# ## Module: collection of functions, classes (variables+methods)

# %%
def add(num1,num2):
  print(num1+num2)

def mul(num1,num2):
  print(num1*num2)

add(100,200)
mul(20,20)
# Out:
# 300
# 400

# %% [markdown]
# ## 1) How to create a module
# ## 2) How to call the functions from one module to another module.
# ## 3)Same functions in 2 modules
#
# #### approach 1: import moduleName
# #### approach 2: from moduleName import functions, classes.

# %%
def fly():
   print("Birds can fly")

def color():
  print("Animal is black")

# %%
import datetime

x = datetime.datetime.now()
print(x)
# Out:
# 2022-12-15 13:29:04.009183

# %% [markdown]
# # PACKAGES: Collection of modules.
#
# ##**Package ---> Modules ----> Functions & Classes**
#
# ### pack1 ==> Module1 ===> display()
# ###       ==> Module2 ===> show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # EXCEPTION HANDLING: exception is an event which will cause program termination.
#
# ### TRY; EXCEPT; ELSE

# %%
print("this is starting of the program")
print("this is starting of the progra")
print("this is starting of the progra")
print(u)
print("this is starting of the progra")
print("this is starting of the progra")
print("this is starting of the progra")
# Out:
# this is starting of the program
# this is starting of the progra
# this is starting of the progra
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-930d2f3df197> in <module>
#       2 print("this is starting of the progra")
#       3 print("this is starting of the progra")
# ----> 4 print(u)
#       5 print("this is starting of the progra")
#       6 print("this is starting of the progra")
#
# NameError: name 'u' is not defined

# %%
#to avoid the error we have got above we use exception.
print("this is starting of the program")
print("this is starting of the progra")
print("this is starting of the progra")
try:
  print(u)
except:
  print("Exception occured")
print("this is starting of the progra")
print("this is starting of the progra")
print("this is starting of the progra")
# Out:
# this is starting of the program
# this is starting of the progra
# this is starting of the progra
# Exception occured
# this is starting of the progra
# this is starting of the progra
# this is starting of the progra

# %%
print("Program starts here!")
print("Program is in progress")
print(10/0)
print("program completed")
# Out:
# Program starts here!
# Program is in progress
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-14-fcfead47582c> in <module>
#       1 print("Program starts here!")
#       2 print("Program is in progress")
# ----> 3 print(10/0)
#       4 print("program completed")
#
# ZeroDivisionError: division by zero

# %%
print("Program starts here!")
print("Program is in progress")
try:
  print(10/0)
except:
  print("Exception occured")
print("program completed")
# Out:
# Program starts here!
# Program is in progress
# Exception occured
# program completed

# %%
#multiple except blocks - try, except, else, finally

try:
  num1,num2=10,0
  result=num1/num2
  print("result is:",result)
except ZeroDivisionError: 
  print("Thrown ZeroDivisionError: Division by zero")
except SyntaxError:
  print("Thrown SyntaxError exception")
except:
  print("Exception handled")
else:
  print("No exceptions occured")
finally:
  print("Always execute")
# Out:
# Thrown ZeroDivisionError: Division by zero
# Always execute

# %% [markdown]
# ## Except ---> Executes only when exception occured.
# ## Else ---> Executes only when exceptions not occured.
# ## Finally ---> Always executes.

# %%
#raising our own exceptions
def enterage(num):
  if num<0:
    raise ValueError("Only Integers are allowed")
  if num%2==0:
    print("even")
  else:
    print("odd")

enterage(10)
enterage(5)
enterage(-1)
# Out:
# even
# odd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-feadf8f977c7> in <module>
#      10 enterage(10)
#      11 enterage(5)
# ---> 12 enterage(-1)
#
# <ipython-input-19-feadf8f977c7> in enterage(num)
#       2 def enterage(num):
#       3   if num<0:
# ----> 4     raise ValueError("Only Integers are allowed")
#       5   if num%2==0:
#       6     print("even")
#
# ValueError: Only Integers are allowed

# %%
# handling the error
#raising our own exceptions
def enterage(num):
  if num<0:
    raise ValueError("Only Integers are allowed")
  if num%2==0:
    print("even")
  else:
    print("odd")
    
print("Checking number is even or odd by calling the function")
num=-1
try:
  enterage(-1)
except ValueError:
  print("Valueerror exception occured and handled")
print("Program Executed Succesfully")
# Out:
# Checking number is even or odd by calling the function
# Valueerror exception occured and handled
# Program Executed Succesfully

# %% [markdown]
# # FILE HANDLING/WORKING WITH THE TEXT

# %%
#Writing data in to text file

#file=open(link location of the file)
#file.write("This is my first statement\n")
#file.write("Second statement\n")
#file.close()
print("program completed")
# Out:
# program completed

# %%
#Reading data from the text file

#file=open(link location of the file)
#print(file.read())
#print(file.readline())
#file.close()
print("program completed")
# Out:
# program completed
